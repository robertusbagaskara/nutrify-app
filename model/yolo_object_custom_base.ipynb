# %% [markdown]
# Mounting Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/yolo_custom_model_training'
# Out:
# backup	Bounding_Box  Bounding_Box.zip	custom_weight  darknet

# %% [markdown]
# Unzip the file

# %%
#!unzip '/content/drive/My Drive/yolo_custom_model_training/Bounding_Box.zip' -d '/content/drive/My Drive/yolo_custom_model_training/'
# Out:
# Archive:  /content/drive/My Drive/yolo_custom_model_training/Bounding_Box.zip
#    creating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/
#    creating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/
#   inflating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/config
#   inflating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/description
#  extracting: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/HEAD
#    creating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/hooks/
#   inflating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/hooks/applypatch-msg.sample
#   inflating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/hooks/commit-msg.sample
#   inflating: /content/drive/My Drive/yolo_custom_model_training/Bounding_Box/.git/hooks/fsmonitor-watchman.sample
# ...

# %% [markdown]
# Cloning the darknet

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolo_custom_model_training/darknet'
# Out:
# Cloning into '/content/drive/My Drive/yolo_custom_model_training/darknet'...
# remote: Enumerating objects: 15054, done.
# remote: Total 15054 (delta 0), reused 0 (delta 0), pack-reused 15054
# Receiving objects: 100% (15054/15054), 13.40 MiB | 7.96 MiB/s, done.
# Resolving deltas: 100% (10233/10233), done.
# Checking out files: 100% (2028/2028), done.

# %%
# %cd /content/drive/My Drive/yolo_custom_model_training/darknet
# Out:
# /content/drive/My Drive/yolo_custom_model_training/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# %cd /content/drive/My Drive/yolo_custom_model_training
# Out:
# /content/drive/My Drive/yolo_custom_model_training

# %%
# !python Bounding_Box/creating-files-data-and-name.py

# %%
# !python Bounding_Box/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# !darknet/darknet detector train Bounding_Box/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 42050, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.907421), count: 1, class_loss = 0.000000, iou_loss = 0.006031, total_loss = 0.006031
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 42051, rewritten_bbox = 0.000000 %
# ...
